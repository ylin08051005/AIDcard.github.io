# %% [markdown]
# <a href="https://colab.research.google.com/github/melody016861/AIDcard.github.io/blob/main/AIDcard_%E8%A9%B3%E7%B4%B0%E7%89%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 智慧回收裝置
#
# [AIDcard網頁](https://github.com/melody016861/AIDcard.github.io)

# %% [markdown]
# 宣傳訊息不僅應關注回收的好處，還應關注
# 說明回收行為如何改變一個人的價值觀和生活方式
# 邁向更好的環境。此外，環保團體可以
# 受邀改善回收活動形象。

# %% [markdown]
# ## 平台功能
#
# 1. 提供使用者上傳回收分類圖片
# 2. 智慧垃圾裝置地圖
# 3. 回收資訊和教育宣導
# 4. 回收記錄(目前只能以手動紀錄)
# 5. 用戶反饋和改善
# 6. 小遊戲
# 7. 爬蟲建立細分類資料集(提供程式碼)

# %% [markdown]
# ## 1️⃣ 提供使用者上傳回收分類圖片
# https://drive.google.com/drive/folders/1ddIq1rjWLzNe3BTafZjxqnx3jMDucKUf?usp=sharing

# %% [markdown]
# ## 2️⃣ 智慧回收裝置地圖
#
#
# > 地圖連結 : https://www.google.com/maps/d/u/0/edit?mid=1BTZKVyuNrLPQ5KOfRFVS22WlTkBYuyM&ll=24.986630218489204%2C121.57500465&z=17
#
#
# 以下提供此地圖的HTML:
#
# ```
# <iframe src="https://www.google.com/maps/d/u/0/embed?mid=1BTZKVyuNrLPQ5KOfRFVS22WlTkBYuyM&ehbc=2E312F" width="640" height="480"></iframe>
# ```

# %% [markdown]
# ## 3️⃣ 回收資訊和教育宣導
#
# ### 介紹
#
# 隨著環境問題日益嚴重，回收已成為我們生活中不可或缺的一部分。通過正確的回收，我們不僅可以減少垃圾焚化場的壓力，還可以保護自然資源。
#
# 隨著科技的進步和環境保護意識的提升，智慧回收裝置成為推動循環經濟和資源再利用的重要工具。智慧回收裝置不僅提高了回收的效率和準確性，還具有教育意義，能夠有效地提升公眾的環保意識和參與度。
#
#
# 希望看到這篇文章的你，可以更了解回收的重要性喔!
#
# ### 回收的重要性
#
# 1. **減少垃圾焚化場壓力**：
#     - 垃圾焚化場是處理廢物的主要方式，但它們佔用了大量的土地資源。
#     - 隨著垃圾量的增加，焚化場的壓力也在不斷增大，目前已到了供不應求的地步。
#
# 2. **保護自然資源**：
#     - 回收有助於保護有限的自然資源，如金屬、木材和石油。
#     - 透過回收，我們可以重新利用這些資源，減少對原材料的需求。
#
# 3. **減少污染**：
#     - 垃圾中的有害物質會污染土壤和水源，對生態環境造成嚴重影響。
#     - 正確回收有害物質可以避免它們對環境的污染。
#
# ### 如何進行有效的回收
#
# 1. **分類回收**：
#     - 將垃圾分為可回收和不可回收兩大類。
#     - 常見的可回收物包括紙張、塑料、金屬和玻璃。
#     - 藉由智慧回收裝置的影像分類，我們可以更有效率的進行回收分類，回收正確率也會大幅提升。
#
# 2. **清潔回收物**：
#     - 在丟棄可回收物之前，應確保它們已經被清潔乾淨。
#     - 這樣可以提高回收物的質量，便於後續的加工處理。
#
# 3. **遵守當地回收規定**：
#     - 每個地區的回收規定可能有所不同，應該了解並遵守當地的回收政策。
#     - 這樣可以確保回收工作的有效性和規範性。
#
# ### 教育宣導的策略
#
# 1. **學校教育**：
#     - 在學校課程中加入環境保護和回收的內容。
#     - 通過實踐活動，如校內回收比賽，提高學生的環保意識。
#
# 2. **社區宣導**：
#     - 組織社區講座和工作坊，向居民傳授回收知識。
#     - 利用社交媒體和社區公告板發布回收資訊和提示。
#
# 3. **企業參與**：
#     - 鼓勵企業參與回收計劃，並提供相應的獎勵措施。
#     - 在辦公室內設置回收站，推動員工參與回收活動。
#
# ### 結論
#
# 回收不僅是解決垃圾問題的一種方式，更是保護環境、節約資源的重要手段。通過教育宣導，我們可以提高公眾的環保意識，促使更多人參與回收行動。讓我們共同努力，為保護地球環境貢獻一份力量吧!

# %% [markdown]
# ## 4️⃣ 回收紀錄
#
# 以**表單填寫**為主，手動更新紀錄智慧回收裝置填滿程度和裝置是否故障。
#
# https://forms.gle/sjDsDTc44PwkEBSP7

# %% [markdown]
# ### 將Google Sheet資料匯入，再利用Python做數據分析

# %%
# 查看gspread版本

import gspread
print(gspread.__version__)
# Out:
# 6.0.2

# %%
# 執行驗證

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
# 步驟二：讀取 Google Sheet 試算表內的資料

# 讀取 google sheet

workbook = gc.open_by_key('1Xho-CHEMF55uVtAkAR_01_fZ_HnEZVBREt4k3wNOxhg')

# 讀取特定的 tab
# sheet = workbook.worksheet('回收紀錄')
# 读取特定的工作表，假设它是第一个工作表（索引为 0）
sheet = workbook.get_worksheet(0)

# %%
# 步驟三：將 Google Sheet 內資料轉變成 Python 內的 DataFrame (表格) 形式

# pandas: 將表格轉換成dataframe來處理

import pandas as pd
values = sheet.get_all_values()
df = pd.DataFrame(values[1:], columns=values[0])

# %%
# Python 數據分析基礎：算術統計

result = df.describe()
result
# Out:
#        時間戳記 電子郵件地址 回收裝置地點  \
# count     0      0      0
# unique    0      0      0
# top     NaN    NaN    NaN
# freq    NaN    NaN    NaN
#
#        回收裝置填滿程度(每格!0%滿，1: 10%, 2: 20%, 3: 30%, 4: 40%, 5: 50%...依此類推)  \
# count                                                   0
# unique                                                  0
# top                                                   NaN
# freq                                                  NaN
#
#        是否回收裝置故障? (請留下地點、回收裝置的種類) 留下email，有問題會通知您
# count                          0               0
# unique                         0               0
# top                          NaN             NaN
# freq                         NaN             NaN

# %% [markdown]
# ## 5️⃣ 用戶反饋和改善

# %% [markdown]
# <>

# %% [markdown]
# ## 6️⃣ 智慧回收小測驗: 發現你的環保潛力!
#
#
# > 表單連結: https://forms.gle/xGWZ9ha8uMon1yWi7
#
# 🌱 您準備好了要發揮您的環保潛力了嗎？參加我們的智慧回收小測驗，為環保事業添磚加瓦吧！透過這個有趣的小遊戲，您將有機會測試您對智慧回收裝置的理解程度，並了解您在環保方面的表現。完成測驗後，您將立即獲得您的得分，並可以了解您在環保知識方面的優勢和不足。
#
# 🌍 為環保事業做貢獻：您的參與不僅僅是為了測試您的知識，更是為了支持環保事業的發展。您的測驗結果將有助於我們更好地了解公眾對智慧回收裝置的理解和需求，為環保宣傳和教育提供更多有針對性的支持。
#
# 💡 即刻獲得反饋：完成測驗後，您將立即獲得您的分數和答題情況的詳細報告。這將幫助您了解您在環保方面的優勢，同時也是一個寶貴的學習機會，讓您更深入地了解環保知識。
#
# 加入我們的智慧回收小測驗，讓我們一起為地球的綠色未來而努力！🌿

# %%
# 步驟二：讀取 Google Sheet 試算表內的資料

# 讀取 google sheet

workbook = gc.open_by_key('1y6XBFT8_lU5IF8kkkSsej3E5Z809ePHH7mgkIBVliWI')

# 讀取特定的 tab
# sheet = workbook.worksheet('回收紀錄')
# 读取特定的工作表，假设它是第一个工作表（索引为 0）
sheet = workbook.get_worksheet(0)

# %%
# 步驟三：將 Google Sheet 內資料轉變成 Python 內的 DataFrame (表格) 形式

# pandas: 將表格轉換成dataframe來處理

import pandas as pd
values = sheet.get_all_values()
df = pd.DataFrame(values[1:], columns=values[0])

# %%
# Python 數據分析基礎：算術統計

result = df.describe()
result
# Out:
#                         時間戳記                  電子郵件地址 請填入你的姓名：      請填入你的電話  \
# count                      1                       1         1           1
# unique                     1                       1         1           1
# top     2024/5/17 下午 6:10:44  melody016861@gmail.com       胡詠琪  0958862539
# freq                       1                       1         1           1
#
#        智慧回收裝置通常使用哪種技術來識別垃圾？         分數 智慧回收裝置的主要目的是？    \
# count                     1          1               1
# unique                    1          1               1
# top                   光學辨識器  100 / 100          提高回收效率
# freq                      1          1               1
#
#        智慧回收裝置通常可以識別和分類哪些類型的垃圾？   智慧回收裝置的運作原理是？   智慧回收裝置在哪些場景中通常會被部署和使用？    \
# count                          1               1                        1
# unique                         1               1                        1
# top                         以上皆是            影像辨識                     以上皆是
# freq                           1               1                        1
#
#        智慧回收裝置通常能識別和分類以下哪些類型的垃圾？    智慧回收裝置如何提高回收效率？   智慧回收裝置通常在以下哪些場景中部署和使用？    \
# count                           1                  1                        1
# unique                          1                  1                        1
# top                紙張, 玻璃, 塑料, 金屬  自動分類垃圾, 增加回收裝置的數量           街道, 商場, 公園, 學校
# freq                            1                  1                        1
#
#        智慧回收裝置的運作原理包括以下哪些？        智慧回收裝置的主要目的是？
# count                     1                    1
# unique                    1                    1
# top       感應器辨識, 重量測量, 影像辨識  提高回收率, 減少垃圾堆積, 保護環境
# freq                      1                    1

# %%
# 將分數字符串按照/分割，並取得相除结果作為整數
scores = df['分數'].str.split('/', expand=True).astype(int).apply(lambda x: int(x[0] / x[1] * 100), axis=1)

# 分析
average_score = scores.mean()  # 平均分
max_score = scores.max()  # 最高分
min_score = scores.min()  # 最低分
score_range = max_score - min_score  # 分數範圍

# 輸出结果
print("平均分:", average_score)
print("最高分:", max_score)
print("最低分:", min_score)
print("分數範圍:", score_range)
# Out:
# 平均分: 100.0
# 最高分: 100
# 最低分: 100
# 分數範圍: 0

# %% [markdown]
# ## 7️⃣ 爬蟲建立細分類資料集

# %% [markdown]
# 根據以下執行結果的<font color="red">**結論**</font> :
# 利用**英文**當作搜尋標籤的成果會**比中文**標籤**更符合**我們要找的圖片。

# %%
# 先下載Request套件，以對網路發送請求
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %%
# Python Beautifulsoup4套件，用來解析網頁的工具
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
# @title 爬蟲後將圖片下載到本機中
import requests
from bs4 import BeautifulSoup
from PIL import Image, ImageDraw, ImageFont
from io import BytesIO
import os

def fetch_image_urls(query, max_links_to_fetch, headers):
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    response = requests.get(search_url, headers=headers)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    image_elements = soup.find_all('img', limit=max_links_to_fetch)
    image_urls = []
    for img in image_elements:
        url = img.get('src') or img.get('data-src')
        if url and url.startswith('http'):
            image_urls.append(url)
    return image_urls

def download_and_label_image(url, label, headers):
    response = requests.get(url, headers=headers)
    img = Image.open(BytesIO(response.content)).convert('RGB')
    draw = ImageDraw.Draw(img)

    # 使用 textbbox 计算文本尺寸
    try:
        text_bbox = draw.textbbox((0, 0), label)
        position = (img.width - (text_bbox[2] - text_bbox[0]) - 10, img.height - (text_bbox[3] - text_bbox[1]) - 10)
        draw.text(position, label, (255, 255, 255))
    except Exception as e:
        print(f"Failed to label image: {e}")

    return img

def main():
    query = "paper recycling"
    max_images = 5
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    save_folder = "labeled_images"
    os.makedirs(save_folder, exist_ok=True)

    print("Fetching image URLs...")
    image_urls = fetch_image_urls(query, max_images, headers)
    print(f"Found {len(image_urls)} images. Downloading and labeling...")

    for i, url in enumerate(image_urls):
        try:
            img = download_and_label_image(url, u"纸類", headers)
            img.save(os.path.join(save_folder, f"paper_recycling_{i + 1}.jpg"))
            print(f"Saved image {i + 1}")
        except Exception as e:
            print(f"Failed to process image {i + 1}: {e}")

    print("Done!")

if __name__ == "__main__":
    main()
# Out:
# Fetching image URLs...
# Found 4 images. Downloading and labeling...
# Failed to label image: 'latin-1' codec can't encode characters in position 0-1: ordinal not in range(256)
# Saved image 1
# Failed to label image: 'latin-1' codec can't encode characters in position 0-1: ordinal not in range(256)
# Saved image 2
# Failed to label image: 'latin-1' codec can't encode characters in position 0-1: ordinal not in range(256)
# Saved image 3
# Failed to label image: 'latin-1' codec can't encode characters in position 0-1: ordinal not in range(256)
# Saved image 4
# Done!

# %% [markdown]
# 爬蟲尋找紙類圖片。利用**繁體中文**爬蟲。

# %%
# @title 原始_5張圖片_爬蟲
import requests
from bs4 import BeautifulSoup
from PIL import Image, ImageDraw, ImageFont
from io import BytesIO
import os
from IPython.display import display

def fetch_image_urls(query, max_links_to_fetch, headers):
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    response = requests.get(search_url, headers=headers)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    image_elements = soup.find_all('img', limit=max_links_to_fetch)
    image_urls = []
    for img in image_elements:
        url = img.get('src') or img.get('data-src')
        if url and url.startswith('http'):
            image_urls.append(url)
    return image_urls

def label_image(img, label):
    draw = ImageDraw.Draw(img)

    # 使用默認字體
    font = ImageFont.load_default()

    # 使用 textbbox 計算文本尺寸
    text_bbox = draw.textbbox((0, 0), label, font=font)
    position = (img.width - text_bbox[2] - 10, img.height - text_bbox[3] - 10)
    draw.text(position, label, (255, 255, 255), font=font)

def display_images_with_labels(image_urls, label):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    for i, url in enumerate(image_urls):
        try:
            response = requests.get(url, headers=headers)
            img = Image.open(BytesIO(response.content)).convert('RGB')
            label_image(img, label.encode('utf-8'))  # 將標籤字符串編碼為UTF-8
            display(img)
            print(f"Displayed image {i + 1}")
        except Exception as e:
            print(f"Failed to process image {i + 1}: {e}")

def main():
    query = "paper recycling"
    max_images = 5
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    print("Fetching image URLs...")
    image_urls = fetch_image_urls(query, max_images, headers)
    print(f"Found {len(image_urls)} images. Displaying images with labels...")

    display_images_with_labels(image_urls, "纸類")

if __name__ == "__main__":
    main()
# Out:
# Fetching image URLs...
# Found 4 images. Displaying images with labels...
# <PIL.Image.Image image mode=RGB size=162x133>
# Displayed image 1
# <PIL.Image.Image image mode=RGB size=162x108>
# Displayed image 2
# <PIL.Image.Image image mode=RGB size=162x91>
# Displayed image 3
# <PIL.Image.Image image mode=RGB size=162x137>
# Displayed image 4

# %%
# @title 原始_100張圖片_爬蟲
import requests
from bs4 import BeautifulSoup
from PIL import Image, ImageDraw, ImageFont
from io import BytesIO
import os
from IPython.display import display

def fetch_image_urls(query, max_links_to_fetch, headers):
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    response = requests.get(search_url, headers=headers)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    image_elements = soup.find_all('img', limit=max_links_to_fetch)
    image_urls = []
    for img in image_elements:
        url = img.get('src') or img.get('data-src')
        if url and url.startswith('http'):
            image_urls.append(url)
    return image_urls

def label_image(img, label):
    draw = ImageDraw.Draw(img)

    # 使用默認字體
    font = ImageFont.load_default()

    # 使用 textbbox 計算文本尺寸
    text_bbox = draw.textbbox((0, 0), label, font=font)
    position = (img.width - text_bbox[2] - 10, img.height - text_bbox[3] - 10)
    draw.text(position, label, (255, 255, 255), font=font)

def display_images_with_labels(image_urls, label):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    for i, url in enumerate(image_urls):
        try:
            response = requests.get(url, headers=headers)
            img = Image.open(BytesIO(response.content)).convert('RGB')
            label_image(img, label.encode('utf-8'))  # 將標籤字符串編碼為UTF-8
            display(img)
            print(f"Displayed image {i + 1}")
        except Exception as e:
            print(f"Failed to process image {i + 1}: {e}")

def main():
    query = "paper recycling"
    max_images = 5
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    print("Fetching image URLs...")
    image_urls = fetch_image_urls(query, max_images, headers)
    print(f"Found {len(image_urls)} images. Displaying images with labels...")

    display_images_with_labels(image_urls, "纸類")

if __name__ == "__main__":
    main()
# Out:
# Fetching image URLs...
# Found 4 images. Displaying images with labels...
# <PIL.Image.Image image mode=RGB size=162x133>
# Displayed image 1
# <PIL.Image.Image image mode=RGB size=162x108>
# Displayed image 2
# <PIL.Image.Image image mode=RGB size=162x91>
# Displayed image 3
# <PIL.Image.Image image mode=RGB size=162x137>
# Displayed image 4

# %%
# @title 爬蟲回收分類image
query = "一般垃圾" # @param ["\u73BB\u7483", "\u7D19\u5F35", "\u7D19\u677F", "\u5851\u81A0", "\u91D1\u5C6C", "\u7D19\u5BB9\u5668", "\u4E00\u822C\u5783\u573E"] {allow-input: true}
import requests
from bs4 import BeautifulSoup
from PIL import Image, ImageDraw, ImageFont
from io import BytesIO
import os
from IPython.display import display

def fetch_image_urls(query, max_links_to_fetch, headers):
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    response = requests.get(search_url, headers=headers)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    image_elements = soup.find_all('img', limit=max_links_to_fetch)
    image_urls = []
    for img in image_elements:
        url = img.get('src') or img.get('data-src')
        if url and url.startswith('http'):
            image_urls.append(url)
    return image_urls

def label_image(img, label):
    draw = ImageDraw.Draw(img)

    # 使用默認字體
    font = ImageFont.load_default()

    # 使用 textbbox 計算文本尺寸
    text_bbox = draw.textbbox((0, 0), label, font=font)
    position = (img.width - text_bbox[2] - 10, img.height - text_bbox[3] - 10)
    draw.text(position, label, (255, 255, 255), font=font)

def display_images_with_labels(image_urls, label):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    for i, url in enumerate(image_urls):
        try:
            response = requests.get(url, headers=headers)
            img = Image.open(BytesIO(response.content)).convert('RGB')
            label_image(img, label.encode('utf-8'))  # 將標籤字符串編碼為UTF-8
            display(img)
            print(f"Displayed image {i + 1}")
        except Exception as e:
            print(f"Failed to process image {i + 1}: {e}")

def main():
    max_images = 100
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    print("Fetching image URLs...")
    image_urls = fetch_image_urls(query, max_images, headers)
    print(f"Found {len(image_urls)} images. Displaying images with labels...")

    display_images_with_labels(image_urls, query)

if __name__ == "__main__":
    main()
# Out:
# Fetching image URLs...
# Found 20 images. Displaying images with labels...
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 1
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 2
# <PIL.Image.Image image mode=RGB size=88x140>
# Displayed image 3
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 4
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 5
# <PIL.Image.Image image mode=RGB size=126x140>
# Displayed image 6
# <PIL.Image.Image image mode=RGB size=103x140>
# Displayed image 7
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 8
# <PIL.Image.Image image mode=RGB size=162x115>
# Displayed image 9
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 10
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 11
# <PIL.Image.Image image mode=RGB size=150x140>
# Displayed image 12
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 13
# <PIL.Image.Image image mode=RGB size=99x140>
# Displayed image 14
# <PIL.Image.Image image mode=RGB size=162x115>
# Displayed image 15
# <PIL.Image.Image image mode=RGB size=162x72>
# Displayed image 16
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 17
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 18
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 19
# <PIL.Image.Image image mode=RGB size=99x140>
# Displayed image 20

# %% [markdown]
# 爬蟲尋找100張紙類圖片。利用繁體中文爬蟲。
#
# ~~<font color="red">需要用Jupyter notebook執行</font>~~

# %%
# @title 爬蟲回收分類_100images
query = "玻璃" # @param ["\u73BB\u7483", "\u7D19\u5F35", "\u7D19\u677F", "\u5851\u81A0", "\u91D1\u5C6C", "\u7D19\u5BB9\u5668", "\u4E00\u822C\u5783\u573E"] {allow-input: true}
import requests
from bs4 import BeautifulSoup
from PIL import Image, ImageDraw, ImageFont
from io import BytesIO
import os
from IPython.display import display

def fetch_image_urls(query, max_links_to_fetch, headers):
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    response = requests.get(search_url, headers=headers)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    image_elements = soup.find_all('img', limit=max_links_to_fetch)
    image_urls = []
    for img in image_elements:
        url = img.get('src') or img.get('data-src')
        if url and url.startswith('http'):
            image_urls.append(url)
    return image_urls

def label_image(img, label):
    draw = ImageDraw.Draw(img)

    # 使用默認字體
    font = ImageFont.load_default()

    # 使用 textbbox 計算文本尺寸
    text_bbox = draw.textbbox((0, 0), label, font=font)
    position = (img.width - text_bbox[2] - 10, img.height - text_bbox[3] - 10)
    draw.text(position, label, (255, 255, 255), font=font)

def display_images_with_labels(image_urls, label):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    for i, url in enumerate(image_urls):
        try:
            response = requests.get(url, headers=headers)
            img = Image.open(BytesIO(response.content)).convert('RGB')
            label_image(img, label.encode('utf-8'))  # 將標籤字符串編碼為UTF-8
            display(img)
            print(f"Displayed image {i + 1}")
        except Exception as e:
            print(f"Failed to process image {i + 1}: {e}")

def main():
    max_images = 100
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    print("Fetching image URLs...")
    image_urls = fetch_image_urls(query, max_images, headers)
    print(f"Found {len(image_urls)} images. Displaying images with labels...")

    display_images_with_labels(image_urls, query)

if __name__ == "__main__":
    main()
# Out:
# Fetching image URLs...
# Found 20 images. Displaying images with labels...
# <PIL.Image.Image image mode=RGB size=116x140>
# Displayed image 1
# <PIL.Image.Image image mode=RGB size=162x108>
# Displayed image 2
# <PIL.Image.Image image mode=RGB size=162x91>
# Displayed image 3
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 4
# <PIL.Image.Image image mode=RGB size=162x108>
# Displayed image 5
# <PIL.Image.Image image mode=RGB size=162x108>
# Displayed image 6
# <PIL.Image.Image image mode=RGB size=162x91>
# Displayed image 7
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 8
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 9
# <PIL.Image.Image image mode=RGB size=162x113>
# Displayed image 10
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 11
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 12
# <PIL.Image.Image image mode=RGB size=162x110>
# Displayed image 13
# <PIL.Image.Image image mode=RGB size=162x108>
# Displayed image 14
# <PIL.Image.Image image mode=RGB size=162x104>
# Displayed image 15
# <PIL.Image.Image image mode=RGB size=162x99>
# Displayed image 16
# <PIL.Image.Image image mode=RGB size=162x107>
# Displayed image 17
# <PIL.Image.Image image mode=RGB size=162x91>
# Displayed image 18
# <PIL.Image.Image image mode=RGB size=162x101>
# Displayed image 19
# <PIL.Image.Image image mode=RGB size=161x140>
# Displayed image 20

# %% [markdown]
# 爬蟲尋找紙類圖片。利用**英文**爬蟲。

# %%
# @title 英文_爬蟲回收分類image
query = "general waste" # @param ["glass", "paper", "cardboard", "plastic", "metal", "paper containers", "general waste"] {allow-input: true}
import requests
from bs4 import BeautifulSoup
from PIL import Image, ImageDraw, ImageFont
from io import BytesIO
import os
from IPython.display import display

def fetch_image_urls(query, max_links_to_fetch, headers):
    search_url = f"https://www.google.com/search?q={query}&tbm=isch"
    response = requests.get(search_url, headers=headers)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')
    image_elements = soup.find_all('img', limit=max_links_to_fetch)
    image_urls = []
    for img in image_elements:
        url = img.get('src') or img.get('data-src')
        if url and url.startswith('http'):
            image_urls.append(url)
    return image_urls

def label_image(img, label):
    draw = ImageDraw.Draw(img)

    # 使用默認字體
    font = ImageFont.load_default()

    # 使用 textbbox 計算文本尺寸
    text_bbox = draw.textbbox((0, 0), label, font=font)
    position = (img.width - text_bbox[2] - 10, img.height - text_bbox[3] - 10)
    draw.text(position, label, (255, 255, 255), font=font)

def display_images_with_labels(image_urls, label):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    for i, url in enumerate(image_urls):
        try:
            response = requests.get(url, headers=headers)
            img = Image.open(BytesIO(response.content)).convert('RGB')
            label_image(img, label.encode('utf-8'))  # 將標籤字符串編碼為UTF-8
            display(img)
            print(f"Displayed image {i + 1}")
        except Exception as e:
            print(f"Failed to process image {i + 1}: {e}")

def main():
    max_images = 20
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}

    print("Fetching image URLs...")
    image_urls = fetch_image_urls(query, max_images, headers)
    print(f"Found {len(image_urls)} images. Displaying images with labels...")

    display_images_with_labels(image_urls, query)

if __name__ == "__main__":
    main()
# Out:
# Fetching image URLs...
# Found 19 images. Displaying images with labels...
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 1
# <PIL.Image.Image image mode=RGB size=162x110>
# Displayed image 2
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 3
# <PIL.Image.Image image mode=RGB size=93x140>
# Displayed image 4
# <PIL.Image.Image image mode=RGB size=162x115>
# Displayed image 5
# <PIL.Image.Image image mode=RGB size=162x108>
# Displayed image 6
# <PIL.Image.Image image mode=RGB size=162x104>
# Displayed image 7
# <PIL.Image.Image image mode=RGB size=162x80>
# Displayed image 8
# <PIL.Image.Image image mode=RGB size=162x93>
# Displayed image 9
# <PIL.Image.Image image mode=RGB size=130x140>
# Displayed image 10
# <PIL.Image.Image image mode=RGB size=162x114>
# Displayed image 11
# <PIL.Image.Image image mode=RGB size=162x130>
# Displayed image 12
# <PIL.Image.Image image mode=RGB size=162x71>
# Displayed image 13
# <PIL.Image.Image image mode=RGB size=105x140>
# Displayed image 14
# <PIL.Image.Image image mode=RGB size=99x140>
# Displayed image 15
# <PIL.Image.Image image mode=RGB size=99x140>
# Displayed image 16
# <PIL.Image.Image image mode=RGB size=162x89>
# Displayed image 17
# <PIL.Image.Image image mode=RGB size=140x140>
# Displayed image 18
# <PIL.Image.Image image mode=RGB size=162x108>
# Displayed image 19
